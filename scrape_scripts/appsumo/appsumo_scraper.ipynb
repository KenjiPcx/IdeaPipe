# %%
import asyncio
import nest_asyncio
from crawl4ai import AsyncWebCrawler
from crawl4ai.extraction_strategy import JsonCssExtractionStrategy, LLMExtractionStrategy
import json
import time
from pydantic import BaseModel, Field

nest_asyncio.apply()
# Out:
# Warning: Synchronous WebCrawler is not available. Install crawl4ai[sync] for synchronous support. However, please note that the synchronous version will be deprecated soon.

# %%
import json

# Load the products from the JSON file
with open('appsumo-products.json', 'r') as file:
    all_products = json.load(file)

# %%
test_data = all_products[:5]
test_data
# Out:
# [{'name': 'Ranklytics',
#   'category': 'SEO',
#   'shortDescription': 'Leverage 200+ ranking signals to generate loads of SEO content that’s ready to rank',
#   'rating': '4.62',
#   'noOfRatings': '60',
#   'price': '$69',
#   'url': 'https://appsumo.com/products/ranklytics/#reviews'},
#  {'name': 'Pismo',
#   'category': 'Productivity',
#   'shortDescription': 'An AI assistant that can rewrite, proofread, and translate whatever you’re writing',
#   'rating': '4.85',
#   'noOfRatings': '84',
#   'price': '$49',
#   'url': 'https://appsumo.com/products/pismo/#reviews'},
#  {'name': 'SiteBehaviour',
#   'category': 'Website analytics',
#   'shortDescription': 'Simplify campaign tracking with this cookie-less alternative to Google Analytics',
#   'rating': '4.7',
#   'noOfRatings': '23',
#   'price': '$49',
#   'url': 'https://appsumo.com/products/sitebehaviour/#reviews'},
#  {'name': 'Butternut AI',
#   'category': 'Web builders',
#   'shortDescription': 'Use this AI platform to build your dream website in seconds with prompts—without any coding',
#   'rating': '4.74',
#   'noOfRatings': '34',
#   'price': '$69',
#   'url': 'https://appsumo.com/products/butternut-ai/#reviews'},
#  {'name': 'VideoToPage',
#   'category': 'Video',
#   'shortDescription': 'Transcribe video and audio to create text content like tutorials, blog posts, or SOPs',
#   'rating': '4.65',
#   'noOfRatings': '17',
#   'price': '$69',
#   'url': 'https://appsumo.com/products/videotopage/#reviews'}]

# %%
import os
import json
import asyncio
from crawl4ai import AsyncWebCrawler
from crawl4ai.extraction_strategy import LLMExtractionStrategy
from pydantic import BaseModel, Field
from typing import List

# Define the Pydantic model for the Butternut AI product
class ButternutAIInfo(BaseModel):
    name: str = Field(description="Product name")
    description: str = Field(description="A detailed description of the product, extract the contents from the TLDR section and also combine it with the description provided in the product page and with your own description")
    unique_value_props: List[str] = Field(description="List of unique value props. Point out how this product is different from your knowledge of common products in the market")
    key_features: List[str] = Field(description="List of key features. Extract from the Core Features section, extract the actual meaningful features")
    best_for: List[str] = Field(description="Best suited for user categories. Extract from the Best For section")
    integrations: List[str] = Field(description="List of integrations. Extract from the Integrations section")
    alternativeTo: List[str] = Field(description="Alternative products. Extract from the Alternative section")
    summaryOfReviews: str = Field(description="Summary from AskSumo. You should be able to extract it from <div class='bg-asksumo'></div>")

# Scraper function to extract product details
async def extract_butternut_ai_info():
    url = 'https://appsumo.com/products/butternut-ai/'

    async with AsyncWebCrawler(verbose=True) as crawler:
        result = await crawler.arun(
            url=url,
            word_count_threshold=1,
            extraction_strategy=LLMExtractionStrategy(
                provider="openai/gpt-4o",  # Replace with your OpenAI model
                api_token=os.getenv('OPENAI_API_KEY'),
                schema=ButternutAIInfo.model_json_schema(),
                extraction_type="schema",
                instruction=(
                    "From the crawled content, extract the product information in the following format: "
                    "name, description, key features (as a list), best for categories (as a list), pricing info, "
                    "integrations (as a list), a summary of AskSumo reviews, and a list of alternative products. "
                    "Ensure that all the data is accurate and reflects the given structure. Example JSON: "
                    '{ "name": "Butternut AI", "description": "A generative AI platform for building websites", '
                    '"key_features": ["AI-driven design", "SEO optimizations", "Custom chatbot"], '
                    '"best_for": ["Small businesses", "Solopreneurs"], "pricing": "$69", '
                    '"integrations": ["Calendly", "Google Analytics", "YouTube"], '
                    '"summaryOfReviews": "Users rate Butternut AI highly for its ease of use.", '
                    '"alternative_to": ["Squarespace", "Wix", "WordPress"] }'
                )
            ),
            bypass_cache=True,
        )

    product_info = json.loads(result.extracted_content)
    print(f"Extracted product information: {product_info}")

    # Save the extracted data
    with open(".data/butternut_ai_info.json", "w", encoding="utf-8") as f:
        json.dump(product_info, f, indent=2)

# Run the asynchronous scraper
asyncio.run(extract_butternut_ai_info())
# Out:
# [LOG] 🌤️  Warming up the AsyncWebCrawler
# [LOG] 🌞 AsyncWebCrawler is ready to crawl
# [LOG] 🕸️ Crawling https://appsumo.com/products/butternut-ai/ using AsyncPlaywrightCrawlerStrategy...
# [LOG] ✅ Crawled https://appsumo.com/products/butternut-ai/ successfully!
# [LOG] 🚀 Crawling done for https://appsumo.com/products/butternut-ai/, success: True, time taken: 7.68 seconds
# [LOG] 🚀 Content extracted for https://appsumo.com/products/butternut-ai/, success: True, time taken: 0.08 seconds
# [LOG] 🔥 Extracting semantic blocks for https://appsumo.com/products/butternut-ai/, Strategy: AsyncWebCrawler
# [LOG] Call LLM for https://appsumo.com/products/butternut-ai/ - block index: 3
# /home/kenji/mambaforge/envs/ideagen/lib/python3.11/site-packages/pydantic/main.py:390: UserWarning: Pydantic serializer warnings:
#   Expected `PromptTokensDetails` but got `dict` with value `{'audio_tokens': None, 'cached_tokens': 0}` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(
# [LOG] Extracted 1 blocks from URL: https://appsumo.com/products/butternut-ai/ block index: 3
# [LOG] Call LLM for https://appsumo.com/products/butternut-ai/ - block index: 4
# [LOG] Extracted 1 blocks from URL: https://appsumo.com/products/butternut-ai/ block index: 4
# [LOG] Call LLM for https://appsumo.com/products/butternut-ai/ - block index: 7
# [LOG] Extracted 1 blocks from URL: https://appsumo.com/products/butternut-ai/ block index: 7
# [LOG] 🚀 Extraction done for https://appsumo.com/products/butternut-ai/, time taken: 12.07 seconds.
# Extracted product information: [{'name': 'Butternut AI', 'description': 'Butternut AI is a generative AI platform designed to simplify the process of building full-fledged, multi-page websites from a single prompt in seconds. It aims to make website building accessible to everyone, regardless of technical expertise, by providing hyper-personalized websites tailored to business niches and target audiences.', 'unique_value_props': ['Generates websites from a single prompt', 'Hyper-personalized design based on business niche', 'Full control over website customization'], 'key_features': ['AI-driven personalized website creation', 'Advanced customization options', 'Fully responsive design for all devices', 'Built-in SEO optimization', 'Seamless integrations for enhanced functionality'], 'best_for': ['Small businesses', 'Entrepreneurs', 'Non-technical users'], 'integrations': ['Custom code', 'Video embedding', 'Calendar embedding'], 'alternativeTo': [], 'summaryOfReviews': '', 'error': False}, {'name': 'Butternut AI', 'description': 'Butternut AI is a generative AI platform that allows users to build stunning, fully-functional websites with zero coding required. It offers features like built-in SEO, tailored content, seamless integrations, and advanced customization options, making it ideal for entrepreneurs, small businesses, and solopreneurs.', 'unique_value_props': ['Generative AI for website creation', 'No coding required', 'SEO-optimized content generation'], 'key_features': ['AI-driven website creation', 'Built-in SEO', 'Tailored content', 'Seamless integrations', 'Advanced customization options'], 'best_for': ['Entrepreneur-curious', 'Small businesses', 'Solopreneurs'], 'integrations': ['Calendly', 'Google Analytics', 'Whatsapp', 'YouTube'], 'alternativeTo': ['Squarespace', 'Wix', 'WordPress'], 'summaryOfReviews': 'Users rate Butternut AI highly for its ease of use and ability to quickly generate professional websites without coding.', 'error': False}, {'name': 'Butternut AI', 'description': 'Butternut AI is a generative AI platform designed to help users build websites quickly and efficiently without any coding. It offers AI-driven design tailored to your business needs, allowing for unlimited content and image generation, advanced SEO optimizations, and compatibility across mobile, tablet, and laptop devices.', 'unique_value_props': ['AI-driven design tailored to business needs', 'Unlimited AI-powered content and image generation', 'Advanced SEO optimizations', 'Custom chatbot trained on website data'], 'key_features': ['AI-driven design', 'Unlimited content and image generation', 'Unlimited edits and regenerations', 'Advanced SEO optimizations', 'Mobile, tablet, and laptop compatibility', 'No Butternut AI branding on live websites', 'CRM for managing users', 'AI-agent', 'Free SSL certificate and hosting', 'Custom chatbot', 'Unlimited website pages with one-click generation'], 'best_for': ['Small businesses', 'Solopreneurs'], 'integrations': ['Google Analytics', 'Calendly', 'YouTube', 'WhatsApp'], 'alternativeTo': ['Squarespace', 'Wix', 'WordPress'], 'summaryOfReviews': 'Users rate Butternut AI highly for its ease of use and the ability to quickly generate websites without coding.'}, {'name': 'Butternut AI', 'description': 'Butternut AI is a platform designed to make website building accessible to everyone, regardless of coding knowledge. It aims to simplify the process of creating modern, aesthetically pleasing websites with an easy-to-use interface.', 'unique_value_props': ['No coding knowledge required', 'Seamless website building experience', 'Empowers users to create without technical barriers'], 'key_features': ['AI-driven website design', 'User-friendly interface', 'Customizable templates'], 'best_for': ['Individuals without coding skills', 'Small business owners', 'Entrepreneurs'], 'integrations': ['Open Source LLMs', 'AWS'], 'alternativeTo': ['Squarespace', 'Wix', 'WordPress'], 'summaryOfReviews': 'Users appreciate ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 57
#      54         json.dump(product_info, f, indent=2)
#      56 # Run the asynchronous scraper
# ---> 57 asyncio.run(extract_butternut_ai_info())
#
# File ~/mambaforge/envs/ideagen/lib/python3.11/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/mambaforge/envs/ideagen/lib/python3.11/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/mambaforge/envs/ideagen/lib/python3.11/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~/mambaforge/envs/ideagen/lib/python3.11/asyncio/tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# Cell In[10], line 53, in extract_butternut_ai_info()
#      50 print(f"Extracted product information: {product_info}")
#      52 # Save the extracted data
# ---> 53 with open(".data/butternut_ai_info.json", "w", encoding="utf-8") as f:
#      54     json.dump(product_info, f, indent=2)
#
# File ~/mambaforge/envs/ideagen/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.data/butternut_ai_info.json'

# %%
import json
import asyncio
from crawl4ai import AsyncWebCrawler
from crawl4ai.extraction_strategy import JsonCssExtractionStrategy

async def scrape_appsumo_product_page(url):
    # Define the extraction schema
    schema = {
    "name": "Butternut AI Product Info",
    "baseSelector": "body",
    "fields": [
        {
            "name": "name",
            "selector": "h1.font-header",
            "type": "text",
        },
        {
            "name": "summary",
            "selector": "div.flex.flex-col.rounded.bg-gray-100.px-4",
            "type": "text",
        },
        {
            "name": "description",
            "selector": "#overview .prose",
            "type": "text",
        },
        {
            "name": "key_features",
            "selector": "#pricePlans ul li",
            "type": "list",
            "fields": [
                {
                    "name": "feature",
                    "type": "text"
                }
            ]
        },
        {
            "name": "audience-integrations-alternativeProducts",
            "selector": "div.grid.grid-cols-1.gap-x-2.gap-y-4 ul",
            "type": "nested_list",
            "fields": [
                {
                    "name": "detail",
                    "selector": "ul.mt-2.list-inside.list-disc li",
                    "type": "list",
                    "fields": [
                        {
                            "name": "item",
                            "type": "text"
                        }
                    ]
                },
            ]
        },
        {
            "name": "summaryOfReviews",
            "selector": ".bg-asksumo",
            "type": "text",
        },
    ],
}

    # Create the extraction strategy
    extraction_strategy = JsonCssExtractionStrategy(schema, verbose=True)
    
    # Use the AsyncWebCrawler with the extraction strategy
    async with AsyncWebCrawler(verbose=True) as crawler:
        result = await crawler.arun(
            url="https://appsumo.com/products/butternut-ai/",
            extraction_strategy=extraction_strategy,
            bypass_cache=True,
        )

        assert result.success, "Failed to crawl the page"

        # Parse the extracted content
        product_info = json.loads(result.extracted_content)
        print(f"Extracted product information: {json.dumps(product_info, indent=2)}")


    return product_info[0]

asyncio.run(scrape_appsumo_product_page("https://appsumo.com/products/butternut-ai/"))
# Out:
# [LOG] 🌤️  Warming up the AsyncWebCrawler
# [LOG] 🌞 AsyncWebCrawler is ready to crawl
# [LOG] 🕸️ Crawling https://appsumo.com/products/butternut-ai/ using AsyncPlaywrightCrawlerStrategy...
# [LOG] ✅ Crawled https://appsumo.com/products/butternut-ai/ successfully!
# [LOG] 🚀 Crawling done for https://appsumo.com/products/butternut-ai/, success: True, time taken: 7.10 seconds
# [LOG] 🚀 Content extracted for https://appsumo.com/products/butternut-ai/, success: True, time taken: 0.08 seconds
# [LOG] 🔥 Extracting semantic blocks for https://appsumo.com/products/butternut-ai/, Strategy: AsyncWebCrawler
# [LOG] 🚀 Extraction done for https://appsumo.com/products/butternut-ai/, time taken: 0.12 seconds.
# Extracted product information: [
#   {
#     "name": "Butternut AI",
#     "summary": "Build a stunning, fully-functional website with zero codeAccess features like built-in SEO, tailored content, seamless integrations, advanced customization options, and more",
#     "description": "Butternut AI is a generative AI platform that can build professional, mobile-ready websites in seconds with simple prompting.Build a website with AIButternut AI gives you everything you need tocreate a website in just seconds\u2014all without writing a line of code.Simply enter text todescribe your business to an advanced AI modelGenerate a fully functional, stunning website with content, images, sections, and layoutsthat align with your business category and target audienceEnter your business name and relevant keywords to generate a full-fledged website in a snap.Get full creative controlEven better, you\u2019ll be able toedit every aspect of your website, including the content, images, components, and layout, to match your creative vision.Add new sections and pages, or tweak the layoutwith the click of a buttonRegenerate the entire websiteuntil you\u2019re satisfied with the visual designCustomize and regenerate website components to perfectly reflect your branding.Optimize sites for any deviceGet your website design fully optimized for desktop, tablet, and mobile devicesDeliver a seamless user experience across the boardAnd the best part is, Butternut AI is capable of building websites for all businesses, no matter the size or industry you\u2019re in.Launch responsive websites that look pixel-perfect on any device.Built-in SEO, right at your fingertipsButternut AIautomates the entire SEO processto ensure your website is optimized for search engines and ready to rank.Automatically complete nine major SEO checksto ensure top rankingsAccess advanced controls for SEOlike robots.txt, sitemap settings, Google verification, and page metadataAutomate your SEO tasks to improve your visibility on search enginesWith only a single prompt, Butternut AI can create a mobile-ready website for your business, optimized for search engines right out the gate.Build your website in seconds.Get lifetime access to Butternut AI today!",
#     "key_features": [
#       {
#         "feature": "Ai-driven design tailored to your business"
#       },
#       {
#         "feature": "Unlimited AI-powered content and image generation"
#       },
#       {
#         "feature": "Unlimited edits and regenerations"
#       },
#       {
#         "feature": "Advanced SEO optimizations"
#       },
#       {
#         "feature": "Mobile, tablet, and laptop compatible websites"
#       },
#       {
#         "feature": "All current and future Basic integrations included: Google Analytics, Calendly, YouTube"
#       },
#       {
#         "feature": "No Butternut AI branding on live websites"
#       },
#       {
#         "feature": "CRM for managing your users"
#       },
#       {
#         "feature": "Ai-agent"
#       },
#       {
#         "feature": "Free SSL certificate and hosting"
#       },
#       {
#         "feature": "Custom chatbot trained on your website data"
#       },
#       {
#         "feature": "Unlimited website pages with one-click generation"
#       }
#     ],
#     "audience-integrations-alternativeProducts": [
#       {
#         "detail": [
#           {
#             "item": "Entrepreneur-curious"
#           },
#           {
#             "item": "Small businesses"
#           },
#           {
#             "item": "Solopreneurs"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "Squarespace"
#           },
#           {
#             "item": "Wix"
#           },
#           {
#             "item": "WordPress"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "Calendly"
#           },
#           {
#             "item": "Google Analytics"
#           },
#           {
#             "item": "Whatsapp"
#           },
#           {
#             "item": "YouTube"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "AI"
#           }
#         ]
#       }
#     ],
#     "summaryOfReviews": "Butternut AI is highly praised for its lightning-fast website creation, advanced customization options, and seamless integrations. Users have highlighted the AI's ability to intelligently understand business niches and target audiences, resulting in hyper-personalized websites. Additionally, the platform offers fully responsive design and built-in SEO to ensure high visibility on search engines. While some users have mentioned minor limitations in design customization and image editing, the overall sentiment is overwhelmingly positive. With an impressive 4.7 rating from 34 reviews, Butternut AI is a solid choice, especially with its 60-day money-back guarantee. Experience the power of AI website building and bring your dreams to life hassle-free!AI-powered summary of customer reviews"
#   }
# ]
# {'name': 'Butternut AI',
#  'summary': 'Build a stunning, fully-functional website with zero codeAccess features like built-in SEO, tailored content, seamless integrations, advanced customization options, and more',
#  'description': 'Butternut AI is a generative AI platform that can build professional, mobile-ready websites in seconds with simple prompting.Build a website with AIButternut AI gives you everything you need tocreate a website in just seconds—all without writing a line of code.Simply enter text todescribe your business to an advanced AI modelGenerate a fully functional, stunning website with content, images, sections, and layoutsthat align with your business category and target audienceEnter your business name and relevant keywords to generate a full-fledged website in a snap.Get full creative controlEven better, you’ll be able toedit every aspect of your website, including the content, images, components, and layout, to match your creative vision.Add new sections and pages, or tweak the layoutwith the click of a buttonRegenerate the entire websiteuntil you’re satisfied with the visual designCustomize and regenerate website components to perfectly reflect your branding.Optimize sites for any deviceGet your website design fully optimized for desktop, tablet, and mobile devicesDeliver a seamless user experience across the boardAnd the best part is, Butternut AI is capable of building websites for all businesses, no matter the size or industry you’re in.Launch responsive websites that look pixel-perfect on any device.Built-in SEO, right at your fingertipsButternut AIautomates the entire SEO processto ensure your website is optimized for search engines and ready to rank.Automatically complete nine major SEO checksto ensure top rankingsAccess advanced controls for SEOlike robots.txt, sitemap settings, Google verification, and page metadataAutomate your SEO tasks to improve your visibility on search enginesWith only a single prompt, Butternut AI can create a mobile-ready website for your business, optimized for search engines right out the gate.Build your website in seconds.Get lifetime access to Butternut AI today!',
#  'key_features': [{'feature': 'Ai-driven design tailored to your business'},
#   {'feature': 'Unlimited AI-powered content and image generation'},
#   {'feature': 'Unlimited edits and regenerations'},
#   {'feature': 'Advanced SEO optimizations'},
#   {'feature': 'Mobile, tablet, and laptop compatible websites'},
#   {'feature': 'All current and future Basic integrations included: Google Analytics, Calendly, YouTube'},
#   {'feature': 'No Butternut AI branding on live websites'},
#   {'feature': 'CRM for managing your users'},
#   {'feature': 'Ai-agent'},
#   {'feature': 'Free SSL certificate and hosting'},
#   {'feature': 'Custom chatbot trained on your website data'},
#   {'feature': 'Unlimited website pages with one-click generation'}],
#  'audience-integrations-alternativeProducts': [{'detail': [{'item': 'Entrepreneur-curious'},
#     {'item': 'Small businesses'},
#     {'item': 'Solopreneurs'}]},
#   {'detail': [{'item': 'Squarespace'},
#     {'item': 'Wix'},
#     {'item': 'WordPress'}]},
#   {'detail': [{'item': 'Calendly'},
#     {'item': 'Google Analytics'},
#     {'item': 'Whatsapp'},
#     {'item': 'YouTube'}]},
#   {'detail': [{'item': 'AI'}]}],
#  'summaryOfReviews': "Butternut AI is highly praised for its lightning-fast website creation, advanced customization options, and seamless integrations. Users have highlighted the AI's ability to intelligently understand business niches and target audiences, resulting in hyper-personalized websites. Additionally, the platform offers fully responsive design and built-in SEO to ensure high visibility on search engines. While some users have mentioned minor limitations in design customization and image editing, the overall sentiment is overwhelmingly positive. With an impressive 4.7 rating from 34 reviews, Butternut AI is a solid choice, especially with its 60-day money-back guarantee. Experience the power of AI website building and bring your dreams to life hassle-free!AI-powered summary of customer reviews"}

# %%
from pydantic import BaseModel, Field
from typing import List

class RefinedProductInfo(BaseModel):
    name: str = Field(description="Name of the product")
    refined_description: str = Field(description="Combined key points from the description, key features, audience, integrations, and alternatives it is replacing")
    potential_usecases: List[str] = Field(description="A few potential use cases where this product would be extremely useful, especially when combined with other technologies")
    ideal_users: List[str] = Field(description="Refined list of ideal customers facing specific issues that will use this product")
    scenarios_where_tool_excels: List[str] = Field(description="Predicted scenarios where this tool stands out and solves specific problems")
    integration_potential: List[str] = Field(description="Predicted ways this tool can effectively integrate with other tools and platforms")
    tags: List[str] = Field(description="Key feature tags to categorize the product")
    
REFINEMENT_PROMPT = """
Analyze the following product information and provide a refined output:

Product Information:
{product_info}

Please provide the following:
1. A refined description that combines key points from the description, key features, audience, integrations, and alternatives it is replacing.
2. Generate 3-5 potential use cases where this product would be extremely useful, especially when combined with other technologies.
3. Further refine the audience and generate 3-5 ideal customer profiles facing specific issues that will use this product.
4. Predict and list 3-5 scenarios where this tool will stand out and solve specific problems.
5. Predict and list 3-5 ways this tool can effectively integrate with other tools and platforms.
6. Add relevant feature tags to categorize the product.

Format your response as a JSON object with the following structure:
{{
    "name": "Product Name",
    "refined_description": "Refined description...",
    "potential_usecases": ["Use case 1", "Use case 2", "Use case 3"],
    "ideal_users": ["Ideal user 1", "Ideal user 2", "Ideal user 3"],
    "scenarios_where_tool_excels": ["Scenario 1", "Scenario 2", "Scenario 3"],
    "integration_potential": ["Integration 1", "Integration 2", "Integration 3"],
    "tags": ["Tag 1", "Tag 2", "Tag 3"],
}}
"""

# %%
from openai import OpenAI
import json
from typing import Dict, Any

client = OpenAI()

async def refine_product_info(product_info: Dict[str, Any]) -> RefinedProductInfo:
    # Ensure your OpenAI API key is set in the environment variables
    del product_info["summaryOfReviews"]

    # Prepare the prompt with the product information
    prompt = REFINEMENT_PROMPT.format(product_info=json.dumps(product_info, indent=2))

    # Make the API call to OpenAI
    response = client.beta.chat.completions.parse(
        model="gpt-4o-mini",  # or whichever model you prefer
        messages=[
            {"role": "system", "content": "You are a helpful AI assistant that analyzes product information and provides refined insights."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.7,
        response_format=RefinedProductInfo,
    )

    return response.choices[0].message.parsed

# %%
# productinput:
#  {'name': 'VideoToPage',
#   'category': 'Video',
#   'shortDescription': 'Transcribe video and audio to create text content like tutorials, blog posts, or SOPs',
#   'rating': '4.65',
#   'noOfRatings': '17',
#   'price': '$69',
#   'url': 'https://appsumo.com/products/videotopage/#reviews'}

async def scrape_pipeline(product: dict):
    scraped_product_info = await scrape_appsumo_product_page(product["url"])
    product["reviewsSummary"] = scraped_product_info["summaryOfReviews"]
    product["name"] = scraped_product_info["name"]

    refined_product_info = await refine_product_info(scraped_product_info)
    product.update(refined_product_info.model_dump())

    return product

# %%
async def main():
    for product in test_data[:3]:
        result = await scrape_pipeline(product)
        print(result)

asyncio.run(main())
# Out:
# [LOG] 🌤️  Warming up the AsyncWebCrawler
# [LOG] 🌞 AsyncWebCrawler is ready to crawl
# [LOG] 🕸️ Crawling https://appsumo.com/products/butternut-ai/ using AsyncPlaywrightCrawlerStrategy...
# [LOG] ✅ Crawled https://appsumo.com/products/butternut-ai/ successfully!
# [LOG] 🚀 Crawling done for https://appsumo.com/products/butternut-ai/, success: True, time taken: 7.62 seconds
# [LOG] 🚀 Content extracted for https://appsumo.com/products/butternut-ai/, success: True, time taken: 0.07 seconds
# [LOG] 🔥 Extracting semantic blocks for https://appsumo.com/products/butternut-ai/, Strategy: AsyncWebCrawler
# [LOG] 🚀 Extraction done for https://appsumo.com/products/butternut-ai/, time taken: 0.12 seconds.
# Extracted product information: [
#   {
#     "name": "Butternut AI",
#     "summary": "Build a stunning, fully-functional website with zero codeAccess features like built-in SEO, tailored content, seamless integrations, advanced customization options, and more",
#     "description": "Butternut AI is a generative AI platform that can build professional, mobile-ready websites in seconds with simple prompting.Build a website with AIButternut AI gives you everything you need tocreate a website in just seconds\u2014all without writing a line of code.Simply enter text todescribe your business to an advanced AI modelGenerate a fully functional, stunning website with content, images, sections, and layoutsthat align with your business category and target audienceEnter your business name and relevant keywords to generate a full-fledged website in a snap.Get full creative controlEven better, you\u2019ll be able toedit every aspect of your website, including the content, images, components, and layout, to match your creative vision.Add new sections and pages, or tweak the layoutwith the click of a buttonRegenerate the entire websiteuntil you\u2019re satisfied with the visual designCustomize and regenerate website components to perfectly reflect your branding.Optimize sites for any deviceGet your website design fully optimized for desktop, tablet, and mobile devicesDeliver a seamless user experience across the boardAnd the best part is, Butternut AI is capable of building websites for all businesses, no matter the size or industry you\u2019re in.Launch responsive websites that look pixel-perfect on any device.Built-in SEO, right at your fingertipsButternut AIautomates the entire SEO processto ensure your website is optimized for search engines and ready to rank.Automatically complete nine major SEO checksto ensure top rankingsAccess advanced controls for SEOlike robots.txt, sitemap settings, Google verification, and page metadataAutomate your SEO tasks to improve your visibility on search enginesWith only a single prompt, Butternut AI can create a mobile-ready website for your business, optimized for search engines right out the gate.Build your website in seconds.Get lifetime access to Butternut AI today!",
#     "key_features": [
#       {
#         "feature": "Lifetime access to Butternut AI"
#       },
#       {
#         "feature": "All future Starter Plan updates"
#       },
#       {
#         "feature": "If Plan name changes, deal will be mapped to the new Plan name with all accompanying updates"
#       },
#       {
#         "feature": "No codes, no stacking\u2014just choose the plan that\u2019s right for you"
#       },
#       {
#         "feature": "You must activate your license within 60 days of purchase"
#       },
#       {
#         "feature": "Ability to upgrade between 4 license tiers while the deal is available"
#       },
#       {
#         "feature": "Ability to downgrade between 4 license tiers within 60 days of purchase"
#       },
#       {
#         "feature": "Only for new Butternut AI users who do not have existing accounts"
#       },
#       {
#         "feature": "AI-driven design tailored to your business"
#       },
#       {
#         "feature": "Unlimited AI-powered content and image generation"
#       },
#       {
#         "feature": "Unlimited edits and regenerations"
#       },
#       {
#         "feature": "Advanced SEO optimizations"
#       },
#       {
#         "feature": "Mobile, tablet, and laptop compatible websites"
#       },
#       {
#         "feature": "All current and future Basic integrations included: Google Analytics, Calendly, YouTube"
#       },
#       {
#         "feature": "No Butternut AI branding on live websites"
#       },
#       {
#         "feature": "CRM for managing your users"
#       },
#       {
#         "feature": "AI-agent"
#       },
#       {
#         "feature": "Free SSL certificate and hosting"
#       },
#       {
#         "feature": "Custom chatbot trained on your website data"
#       },
#       {
#         "feature": "Unlimited website pages with one-click generation"
#       }
#     ],
#     "audience-integrations-alternativeProducts": [
#       {
#         "detail": [
#           {
#             "item": "Entrepreneur-curious"
#           },
#           {
#             "item": "Small businesses"
#           },
#           {
#             "item": "Solopreneurs"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "Squarespace"
#           },
#           {
#             "item": "Wix"
#           },
#           {
#             "item": "WordPress"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "Calendly"
#           },
#           {
#             "item": "Google Analytics"
#           },
#           {
#             "item": "Whatsapp"
#           },
#           {
#             "item": "YouTube"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "AI"
#           }
#         ]
#       }
#     ],
#     "summaryOfReviews": "Butternut AI is highly praised for its lightning-fast website creation, advanced customization options, and seamless integrations. Users have highlighted the AI's ability to intelligently understand business niches and target audiences, resulting in hyper-personalized websites. Additionally, the platform offers fully responsive design and built-in SEO to ensure high visibility on search engines. While some users have mentioned minor limitations in design customization and image editing, the overall sentiment is overwhelmingly positive. With an impressive 4.7 rating from 34 reviews, Butternut AI is a solid choice, especially with its 60-day money-back guarantee. Experience the power of AI website building and bring your dreams to life hassle-free!AI-powered summary of customer reviews"
#   }
# ]
# {'name': 'Butternut AI', 'category': 'SEO', 'shortDescription': 'Leverage 200+ ranking signals to generate loads of SEO content that’s ready to rank', 'rating': '4.62', 'noOfRatings': '60', 'price': '$69', 'url': 'https://appsumo.com/products/ranklytics/#reviews', 'reviewsSummary': "Butternut AI is highly praised for its lightning-fast website creation, advanced customization options, and seamless integrations. Users have highlighted the AI's ability to intelligently understand business niches and target audiences, resulting in hyper-personalized websites. Additionally, the platform offers fully responsive design and built-in SEO to ensure high visibility on search engines. While some users have mentioned minor limitations in design customization and image editing, the overall sentiment is overwhelmingly positive. With an impressive 4.7 rating from 34 reviews, Butternut AI is a solid choice, especially with its 60-day money-back guarantee. Experience the power of AI website building and bring your dreams to life hassle-free!AI-powered summary of customer reviews", 'refined_description': 'Butternut AI is a generative AI platform designed for entrepreneurs, small businesses, and solopreneurs that enables users to create stunning, professional websites without any coding knowledge. With features such as unlimited content generation, advanced SEO optimizations, mobile compatibility, and seamless integrations with tools like Google Analytics and Calendly, Butternut AI simplifies the website creation process. It replaces traditional website builders like Squarespace, Wix, and WordPress by offering an AI-driven, customizable solution that automates design and optimization tasks, ensuring high-quality results in just seconds.', 'potential_usecases': ['Creating a website for a new small business or startup quickly and efficiently.', "Updating and optimizing an existing website's SEO without technical expertise.", 'Launching a personal portfolio or blog with minimal effort and maximum customization.', 'Building a landing page for a marketing campaign that needs to go live immediately.', 'Creating multiple niche websites for affiliate marketing with tailored content.'], 'ideal_users': ['Entrepreneurs looking to establish an online presence quickly.', 'Small business owners who lack technical skills but want a professional website.', 'Solopreneurs who need to create and manage their own websites without hiring developers.', 'Freelancers wanting to showcase their work through a personalized website.'], 'scenarios_where_tool_excels': ['When a user needs to launch a website within a tight deadline.', 'For users who want to create multiple websites easily and with consistent branding.', 'In situations where SEO optimization is critical for business visibility and traffic generation.', 'When users require a high level of customization without the need for coding knowledge.'], 'integration_potential': ['Connecting with Google Analytics for tracking website performance and user behavior.', 'Integrating with Calendly for scheduling appointments directly from the website.', 'Embedding YouTube videos seamlessly into the website for enhanced content.', 'Using WhatsApp integration for customer service and communication directly from the site.'], 'tags': ['No-code website builder', 'AI-driven design', 'SEO optimization', 'Mobile-ready', 'Unlimited customization']}
# [LOG] 🌤️  Warming up the AsyncWebCrawler
# [LOG] 🌞 AsyncWebCrawler is ready to crawl
# [LOG] 🕸️ Crawling https://appsumo.com/products/butternut-ai/ using AsyncPlaywrightCrawlerStrategy...
# [LOG] ✅ Crawled https://appsumo.com/products/butternut-ai/ successfully!
# [LOG] 🚀 Crawling done for https://appsumo.com/products/butternut-ai/, success: True, time taken: 7.07 seconds
# [LOG] 🚀 Content extracted for https://appsumo.com/products/butternut-ai/, success: True, time taken: 0.07 seconds
# [LOG] 🔥 Extracting semantic blocks for https://appsumo.com/products/butternut-ai/, Strategy: AsyncWebCrawler
# [LOG] 🚀 Extraction done for https://appsumo.com/products/butternut-ai/, time taken: 0.12 seconds.
# Extracted product information: [
#   {
#     "name": "Butternut AI",
#     "summary": "Build a stunning, fully-functional website with zero codeAccess features like built-in SEO, tailored content, seamless integrations, advanced customization options, and more",
#     "description": "Butternut AI is a generative AI platform that can build professional, mobile-ready websites in seconds with simple prompting.Build a website with AIButternut AI gives you everything you need tocreate a website in just seconds\u2014all without writing a line of code.Simply enter text todescribe your business to an advanced AI modelGenerate a fully functional, stunning website with content, images, sections, and layoutsthat align with your business category and target audienceEnter your business name and relevant keywords to generate a full-fledged website in a snap.Get full creative controlEven better, you\u2019ll be able toedit every aspect of your website, including the content, images, components, and layout, to match your creative vision.Add new sections and pages, or tweak the layoutwith the click of a buttonRegenerate the entire websiteuntil you\u2019re satisfied with the visual designCustomize and regenerate website components to perfectly reflect your branding.Optimize sites for any deviceGet your website design fully optimized for desktop, tablet, and mobile devicesDeliver a seamless user experience across the boardAnd the best part is, Butternut AI is capable of building websites for all businesses, no matter the size or industry you\u2019re in.Launch responsive websites that look pixel-perfect on any device.Built-in SEO, right at your fingertipsButternut AIautomates the entire SEO processto ensure your website is optimized for search engines and ready to rank.Automatically complete nine major SEO checksto ensure top rankingsAccess advanced controls for SEOlike robots.txt, sitemap settings, Google verification, and page metadataAutomate your SEO tasks to improve your visibility on search enginesWith only a single prompt, Butternut AI can create a mobile-ready website for your business, optimized for search engines right out the gate.Build your website in seconds.Get lifetime access to Butternut AI today!",
#     "key_features": [
#       {
#         "feature": "Ai-driven design tailored to your business"
#       },
#       {
#         "feature": "Unlimited AI-powered content and image generation"
#       },
#       {
#         "feature": "Unlimited edits and regenerations"
#       },
#       {
#         "feature": "Advanced SEO optimizations"
#       },
#       {
#         "feature": "Mobile, tablet, and laptop compatible websites"
#       },
#       {
#         "feature": "All current and future Basic integrations included: Google Analytics, Calendly, YouTube"
#       },
#       {
#         "feature": "No Butternut AI branding on live websites"
#       },
#       {
#         "feature": "CRM for managing your users"
#       },
#       {
#         "feature": "Ai-agent"
#       },
#       {
#         "feature": "Free SSL certificate and hosting"
#       },
#       {
#         "feature": "Custom chatbot trained on your website data"
#       },
#       {
#         "feature": "Unlimited website pages with one-click generation"
#       }
#     ],
#     "audience-integrations-alternativeProducts": [
#       {
#         "detail": [
#           {
#             "item": "Entrepreneur-curious"
#           },
#           {
#             "item": "Small businesses"
#           },
#           {
#             "item": "Solopreneurs"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "Squarespace"
#           },
#           {
#             "item": "Wix"
#           },
#           {
#             "item": "WordPress"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "Calendly"
#           },
#           {
#             "item": "Google Analytics"
#           },
#           {
#             "item": "Whatsapp"
#           },
#           {
#             "item": "YouTube"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "AI"
#           }
#         ]
#       }
#     ],
#     "summaryOfReviews": "Butternut AI is highly praised for its lightning-fast website creation, advanced customization options, and seamless integrations. Users have highlighted the AI's ability to intelligently understand business niches and target audiences, resulting in hyper-personalized websites. Additionally, the platform offers fully responsive design and built-in SEO to ensure high visibility on search engines. While some users have mentioned minor limitations in design customization and image editing, the overall sentiment is overwhelmingly positive. With an impressive 4.7 rating from 34 reviews, Butternut AI is a solid choice, especially with its 60-day money-back guarantee. Experience the power of AI website building and bring your dreams to life hassle-free!AI-powered summary of customer reviews"
#   }
# ]
# {'name': 'Butternut AI', 'category': 'Productivity', 'shortDescription': 'An AI assistant that can rewrite, proofread, and translate whatever you’re writing', 'rating': '4.85', 'noOfRatings': '84', 'price': '$49', 'url': 'https://appsumo.com/products/pismo/#reviews', 'reviewsSummary': "Butternut AI is highly praised for its lightning-fast website creation, advanced customization options, and seamless integrations. Users have highlighted the AI's ability to intelligently understand business niches and target audiences, resulting in hyper-personalized websites. Additionally, the platform offers fully responsive design and built-in SEO to ensure high visibility on search engines. While some users have mentioned minor limitations in design customization and image editing, the overall sentiment is overwhelmingly positive. With an impressive 4.7 rating from 34 reviews, Butternut AI is a solid choice, especially with its 60-day money-back guarantee. Experience the power of AI website building and bring your dreams to life hassle-free!AI-powered summary of customer reviews", 'refined_description': 'Butternut AI is a generative AI platform that allows users to build stunning, fully-functional websites without any coding experience. It offers AI-driven design tailored to specific business needs, unlimited content and image generation, advanced SEO optimizations, and seamless integrations with tools like Google Analytics and Calendly. This platform is ideal for entrepreneurs, small businesses, and solopreneurs looking to establish a professional online presence quickly and efficiently.', 'potential_usecases': ['Creating a professional portfolio site for freelancers combining Butternut AI with social media analytics tools.', 'Building an e-commerce site for small businesses alongside payment gateways and inventory management systems.', 'Developing a service-based website for consultants that integrates with scheduling tools like Calendly.', 'Launching a blog that requires SEO optimization and content generation using AI capabilities.', 'Setting up a landing page for marketing campaigns that links with CRM systems for lead management.'], 'ideal_users': ['Entrepreneurs seeking to quickly establish a business online without technical skills.', 'Small business owners wanting an affordable way to create a professional website.', 'Solopreneurs looking for a comprehensive platform to manage their online presence.', 'Freelancers who require a portfolio site that showcases their work effortlessly.', 'Marketers aiming to launch promotional websites that need to be optimized for SEO.'], 'scenarios_where_tool_excels': ['When a user needs to launch a website quickly for an upcoming event or promotion.', 'For businesses that require frequent website updates without the need for technical support.', 'In situations where users want to create multiple websites for different business ventures from a single platform.', 'When a user needs advanced SEO features integrated directly into their website without additional tools.', 'For startups that lack the budget for web development, yet need a robust online presence.'], 'integration_potential': ['Integrating with Google Analytics for tracking website performance and user engagement.', 'Connecting with payment processing tools for e-commerce solutions.', 'Working alongside CRM systems to manage customer interactions and data effectively.', 'Linking with social media platforms for enhanced marketing and audience engagement.', 'Integrating with email marketing tools to streamline communication with visitors.'], 'tags': ['No-Code Website Builder', 'SEO Optimization', 'AI-Powered Design', 'Responsive Design', 'Business Solutions']}
# [LOG] 🌤️  Warming up the AsyncWebCrawler
# [LOG] 🌞 AsyncWebCrawler is ready to crawl
# [LOG] 🕸️ Crawling https://appsumo.com/products/butternut-ai/ using AsyncPlaywrightCrawlerStrategy...
# [LOG] ✅ Crawled https://appsumo.com/products/butternut-ai/ successfully!
# [LOG] 🚀 Crawling done for https://appsumo.com/products/butternut-ai/, success: True, time taken: 7.02 seconds
# [LOG] 🚀 Content extracted for https://appsumo.com/products/butternut-ai/, success: True, time taken: 0.07 seconds
# [LOG] 🔥 Extracting semantic blocks for https://appsumo.com/products/butternut-ai/, Strategy: AsyncWebCrawler
# [LOG] 🚀 Extraction done for https://appsumo.com/products/butternut-ai/, time taken: 0.22 seconds.
# Extracted product information: [
#   {
#     "name": "Butternut AI",
#     "summary": "Build a stunning, fully-functional website with zero codeAccess features like built-in SEO, tailored content, seamless integrations, advanced customization options, and more",
#     "description": "Butternut AI is a generative AI platform that can build professional, mobile-ready websites in seconds with simple prompting.Build a website with AIButternut AI gives you everything you need tocreate a website in just seconds\u2014all without writing a line of code.Simply enter text todescribe your business to an advanced AI modelGenerate a fully functional, stunning website with content, images, sections, and layoutsthat align with your business category and target audienceEnter your business name and relevant keywords to generate a full-fledged website in a snap.Get full creative controlEven better, you\u2019ll be able toedit every aspect of your website, including the content, images, components, and layout, to match your creative vision.Add new sections and pages, or tweak the layoutwith the click of a buttonRegenerate the entire websiteuntil you\u2019re satisfied with the visual designCustomize and regenerate website components to perfectly reflect your branding.Optimize sites for any deviceGet your website design fully optimized for desktop, tablet, and mobile devicesDeliver a seamless user experience across the boardAnd the best part is, Butternut AI is capable of building websites for all businesses, no matter the size or industry you\u2019re in.Launch responsive websites that look pixel-perfect on any device.Built-in SEO, right at your fingertipsButternut AIautomates the entire SEO processto ensure your website is optimized for search engines and ready to rank.Automatically complete nine major SEO checksto ensure top rankingsAccess advanced controls for SEOlike robots.txt, sitemap settings, Google verification, and page metadataAutomate your SEO tasks to improve your visibility on search enginesWith only a single prompt, Butternut AI can create a mobile-ready website for your business, optimized for search engines right out the gate.Build your website in seconds.Get lifetime access to Butternut AI today!",
#     "key_features": [
#       {
#         "feature": "Ai-driven design tailored to your business"
#       },
#       {
#         "feature": "Unlimited AI-powered content and image generation"
#       },
#       {
#         "feature": "Unlimited edits and regenerations"
#       },
#       {
#         "feature": "Advanced SEO optimizations"
#       },
#       {
#         "feature": "Mobile, tablet, and laptop compatible websites"
#       },
#       {
#         "feature": "All current and future Basic integrations included: Google Analytics, Calendly, YouTube"
#       },
#       {
#         "feature": "No Butternut AI branding on live websites"
#       },
#       {
#         "feature": "CRM for managing your users"
#       },
#       {
#         "feature": "Ai-agent"
#       },
#       {
#         "feature": "Free SSL certificate and hosting"
#       },
#       {
#         "feature": "Custom chatbot trained on your website data"
#       },
#       {
#         "feature": "Unlimited website pages with one-click generation"
#       }
#     ],
#     "audience-integrations-alternativeProducts": [
#       {
#         "detail": [
#           {
#             "item": "Entrepreneur-curious"
#           },
#           {
#             "item": "Small businesses"
#           },
#           {
#             "item": "Solopreneurs"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "Squarespace"
#           },
#           {
#             "item": "Wix"
#           },
#           {
#             "item": "WordPress"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "Calendly"
#           },
#           {
#             "item": "Google Analytics"
#           },
#           {
#             "item": "Whatsapp"
#           },
#           {
#             "item": "YouTube"
#           }
#         ]
#       },
#       {
#         "detail": [
#           {
#             "item": "AI"
#           }
#         ]
#       }
#     ],
#     "summaryOfReviews": "Butternut AI is highly praised for its lightning-fast website creation, advanced customization options, and seamless integrations. Users have highlighted the AI's ability to intelligently understand business niches and target audiences, resulting in hyper-personalized websites. Additionally, the platform offers fully responsive design and built-in SEO to ensure high visibility on search engines. While some users have mentioned minor limitations in design customization and image editing, the overall sentiment is overwhelmingly positive. With an impressive 4.7 rating from 34 reviews, Butternut AI is a solid choice, especially with its 60-day money-back guarantee. Experience the power of AI website building and bring your dreams to life hassle-free!AI-powered summary of customer reviews"
#   }
# ]
# {'name': 'Butternut AI', 'category': 'Website analytics', 'shortDescription': 'Simplify campaign tracking with this cookie-less alternative to Google Analytics', 'rating': '4.7', 'noOfRatings': '23', 'price': '$49', 'url': 'https://appsumo.com/products/sitebehaviour/#reviews', 'reviewsSummary': "Butternut AI is highly praised for its lightning-fast website creation, advanced customization options, and seamless integrations. Users have highlighted the AI's ability to intelligently understand business niches and target audiences, resulting in hyper-personalized websites. Additionally, the platform offers fully responsive design and built-in SEO to ensure high visibility on search engines. While some users have mentioned minor limitations in design customization and image editing, the overall sentiment is overwhelmingly positive. With an impressive 4.7 rating from 34 reviews, Butternut AI is a solid choice, especially with its 60-day money-back guarantee. Experience the power of AI website building and bring your dreams to life hassle-free!AI-powered summary of customer reviews", 'refined_description': 'Butternut AI is a generative AI platform designed to help entrepreneurs, small businesses, and solopreneurs create stunning, fully-functional websites without any coding. With features like AI-driven design, automated SEO optimizations, unlimited content and image generation, and seamless integrations with popular tools like Google Analytics and Calendly, Butternut AI empowers users to build responsive websites tailored to their branding and business needs in mere seconds.', 'potential_usecases': ['Quickly launch a professional website for a new startup without hiring a developer.', 'Generate multiple variations of a website to test different designs and content strategies.', 'Create a landing page for a marketing campaign that can be built and optimized in real-time.', "Develop a portfolio website that showcases a freelancer's work with minimal effort.", 'Easily manage and update a small business website, keeping it fresh and SEO-friendly with little ongoing maintenance.'], 'ideal_users': ['Entrepreneurs looking to establish an online presence quickly and affordably.', 'Small business owners who want to create a professional website without technical skills.', 'Solopreneurs needing a personal brand website that is easily customizable.', 'Non-technical marketers who want to launch and optimize landing pages.', 'Freelancers wanting to showcase their work without the hassle of web development.'], 'scenarios_where_tool_excels': ['When a user needs to launch a website rapidly for an upcoming product launch or event.', 'In situations where a business requires frequent updates to its website content and layout.', 'For users who want to test different website designs and layouts without significant investment.', 'When optimizing existing websites for SEO and mobile compatibility with minimal effort.', 'In cases where businesses want to automate their website management and maintenance tasks.'], 'integration_potential': ['Integrate with Google Analytics for tracking website performance and user behavior.', 'Connect with Calendly to manage appointments directly from the website.', 'Utilize YouTube for embedding video content seamlessly on the website.', 'Incorporate WhatsApp for direct communication and customer support through the website.', 'Link with CRM systems for managing customer interactions and data effectively.'], 'tags': ['AI Website Builder', 'No-Code Development', 'SEO Optimization', 'Responsive Design', 'Content Generation']}
